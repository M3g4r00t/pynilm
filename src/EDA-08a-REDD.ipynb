# %%
import warnings
warnings.filterwarnings(action="ignore")

import os
import json
import pandas as pd
import numpy as np
from tensorflow.keras.applications import VGG16, ResNet50
from tensorflow.keras.applications.vgg16 import preprocess_input as vgg_preprocess
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, confusion_matrix
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from PIL import Image
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import cv2
from concurrent.futures import ThreadPoolExecutor

# %%
# Verificar que TensorFlow puede detectar la GPU
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
# Cargar el DataFrame
df_train = pd.read_csv('../data/train_value_min_label_windows_112.csv')
df_test = pd.read_csv('../data/test_value_min_label_windows_112.csv')
#labels = [c for c in df_train.columns.values if not c in ['row']]
appliances = ['Fridge01','Dish washer01','Microwave01','Washer dryer01','Washer dryer02']

df_train['valid'] = 0
for label in appliances:
    df_train.loc[df_train[label] == 1, 'valid'] = 1

df_filtered_train = df_train[df_train['valid'] == 1]

# %%
df_filtered_train = df_filtered_train.sample(frac=0.5, random_state=42)
df_filtered_test = df_filtered_train.sample(frac=0.1, random_state=42)

# %%
# Modelo preentrenado (usar VGG16 o ResNet50)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
model = Model(inputs=base_model.input, outputs=base_model.output)

# %%
# Función para cargar y procesar imágenes
def load_and_process_image(image_folder, img_name):
    # Paths to images
    img_r_path = os.path.join(image_folder, f"{img_name}_rp.png")
    img_g_path = os.path.join(image_folder, f"{img_name}_gasf.png")
    img_b_path = os.path.join(image_folder, f"{img_name}_gadf.png")
    
    # Load and resize images using OpenCV for speed
    img_r = cv2.imread(img_r_path, cv2.IMREAD_GRAYSCALE)
    img_g = cv2.imread(img_g_path, cv2.IMREAD_GRAYSCALE)
    img_b = cv2.imread(img_b_path, cv2.IMREAD_GRAYSCALE)
    
    # Resize images to 224x224
    img_r = cv2.resize(img_r, (224, 224))
    img_g = cv2.resize(img_g, (224, 224))
    img_b = cv2.resize(img_b, (224, 224))
    
    # Merge channels
    img_rgb = cv2.merge([img_r, img_g, img_b])
    
    # Convert to array and expand dimensions
    img_array = img_to_array(img_rgb)

    # Reduce memory usage by converting to uint8
    img_array = img_array.astype(np.float16)
    
    img_array = np.expand_dims(img_array, axis=0)
    
    # Preprocess for VGG16
    img_array = vgg_preprocess(img_array)
    
    return img_array

# %%
# Batch processing with threading to load and process multiple images in parallel
def load_and_process_images_in_parallel(image_folder, image_names, max_workers=1):
    processed_images = []
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(load_and_process_image, image_folder, img_name) for img_name in image_names]
        for future in futures:
            processed_images.append(future.result())
    
    return np.vstack(processed_images)  # Combine all processed images into a single array

# %%
# Extraer características
features = []
#img_array = []
for image_name in df_filtered_train['row']:
    img_array = load_and_process_image('../data/v5/window_size_112/train/all',image_name)
    feature = model.predict(img_array)
    features.append(feature.flatten())
# Convertir a array numpy
X = np.array(features)
#img_array_train = np.array(img_array)
#X = load_and_process_images_in_parallel('../data/v5/window_size_112/train/all', df_filtered_train['row'])

# %%
# Extraer características
features = []
for image_name in df_filtered_test['row']:
    img_array = load_and_process_image('../data/v5/window_size_112/test/all',image_name)
    feature = model.predict(img_array)
    features.append(feature.flatten())
# Convertir a array numpy
X_test = np.array(features)
#X_test = load_and_process_images_in_parallel('../data/v5/window_size_112/test/all', df_filtered_test['row'])

# %%
# Separar las columnas de etiquetas
labels_train = df_filtered_train.drop(columns=['row'])
labels_test = df_filtered_test.drop(columns=['row'])
# Diccionario para almacenar los resultados
results = {}

# %%
# Archivo para guardar los resultados
results_file = '../data/v5/model_results_window_size_112_vgg.json'

# %%
# Cargar resultados existentes
if os.path.exists(results_file):
    with open(results_file, 'r') as f:
        results = json.load(f)

# %%
# Función para guardar los resultados
def save_results(results):
    with open(results_file, 'w') as f:
        json.dump(results, f, indent=4)

# %%
X.shape, X_test.shape
# Out:
# ((19581, 25088), (1958, 25088))

# %%
from sklearn.utils import resample

# Function to handle errors in AUC
def safe_roc_auc_score(y_true, y_pred):
    try:
        return roc_auc_score(y_true, y_pred)
    except ValueError as e:
        return np.nan

# Entrenar y evaluar modelos para cada columna
X_test = X_test
for a in appliances:
    if a in results:
        print(f"Results for appliance {a} already exist. Skipping training.")
        continue
    else:
        print(f"Training process for appliance {a}.")

    y = labels_train[a]
    y_test = labels_test[a]    
    
    # Split data into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
    
    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)
    
    # Initialize MLPClassifier
    mlp = MLPClassifier(hidden_layer_sizes=(16, 8),  # Configuración con dos capas ocultas
                        max_iter=1,  # Start with 1 iteration and increase iteratively
                        learning_rate_init=0.001,
                        solver='adam',
                        alpha=0.01,
                        random_state=42,
                        warm_start=True)  # To continue training in subsequent iterations
    
    # Early stopping parameters
    patience = 20
    best_val_score = -np.inf
    epochs_no_improve = 0
    max_epochs = 100  # Total number of epochs to train
    
    for epoch in range(max_epochs):
        # Train the model
        mlp.fit(X_train_scaled, y_train)
        
        # Evaluate on validation set
        val_predictions = mlp.predict(X_val_scaled)
        val_accuracy = accuracy_score(y_val, val_predictions)
        val_auc = safe_roc_auc_score(y_val, val_predictions)
        
        print(f"Epoch {epoch+1}/{max_epochs} - Validation Accuracy: {val_accuracy:.4f} - Validation AUC: {val_auc:.4f}")
        
        # Check for improvement
        if val_auc > best_val_score:
            best_val_score = val_auc
            epochs_no_improve = 0
            # Save the best model weights
            best_model = mlp
        else:
            epochs_no_improve += 1
        
        # Check early stopping condition
        if epochs_no_improve >= patience:
            print("Early stopping triggered.")
            break
    
    # Use the best model for prediction
    y_pred_mlp = best_model.predict(X_test_scaled)
    
    # Evaluación
    metrics = {
        'MLP': {
            'accuracy': accuracy_score(y_test, y_pred_mlp),
            'auc': safe_roc_auc_score(y_test, y_pred_mlp),
            'f1_score': f1_score(y_test, y_pred_mlp),
            'confusion_matrix': confusion_matrix(y_test, y_pred_mlp).tolist()  # Convertir a lista para guardar en JSON
        }
    }

    # Store results
    results[a] = metrics

    # Save results after each column
    save_results(results)  # Assuming this function is defined elsewhere
# Out:
# Training process for appliance Fridge01.
# Epoch 1/100 - Validation Accuracy: 0.9139 - Validation AUC: 0.5291
# Epoch 2/100 - Validation Accuracy: 0.9197 - Validation AUC: 0.6032
# Epoch 3/100 - Validation Accuracy: 0.9142 - Validation AUC: 0.6203
# Epoch 4/100 - Validation Accuracy: 0.9098 - Validation AUC: 0.6179
# Epoch 5/100 - Validation Accuracy: 0.9079 - Validation AUC: 0.6019
# Epoch 6/100 - Validation Accuracy: 0.9180 - Validation AUC: 0.5973
# Epoch 7/100 - Validation Accuracy: 0.9265 - Validation AUC: 0.6480
# Epoch 8/100 - Validation Accuracy: 0.9304 - Validation AUC: 0.6301
# Epoch 9/100 - Validation Accuracy: 0.9319 - Validation AUC: 0.6372
# Epoch 10/100 - Validation Accuracy: 0.9253 - Validation AUC: 0.6424
# Epoch 11/100 - Validation Accuracy: 0.9256 - Validation AUC: 0.6563
# Epoch 12/100 - Validation Accuracy: 0.9140 - Validation AUC: 0.6575
# Epoch 13/100 - Validation Accuracy: 0.9180 - Validation AUC: 0.6509
# Epoch 14/100 - Validation Accuracy: 0.9231 - Validation AUC: 0.6374
# Epoch 15/100 - Validation Accuracy: 0.9297 - Validation AUC: 0.6248
# Epoch 16/100 - Validation Accuracy: 0.9283 - Validation AUC: 0.6129
# Epoch 17/100 - Validation Accuracy: 0.9234 - Validation AUC: 0.6526
# Epoch 18/100 - Validation Accuracy: 0.9287 - Validation AUC: 0.6267
# Epoch 19/100 - Validation Accuracy: 0.9169 - Validation AUC: 0.6367
# Epoch 20/100 - Validation Accuracy: 0.9217 - Validation AUC: 0.6492
# Epoch 21/100 - Validation Accuracy: 0.9256 - Validation AUC: 0.6201
# Epoch 22/100 - Validation Accuracy: 0.9294 - Validation AUC: 0.6209
# Epoch 23/100 - Validation Accuracy: 0.9251 - Validation AUC: 0.6298
# Epoch 24/100 - Validation Accuracy: 0.9290 - Validation AUC: 0.6232
# Epoch 25/100 - Validation Accuracy: 0.9273 - Validation AUC: 0.6335
# Epoch 26/100 - Validation Accuracy: 0.9251 - Validation AUC: 0.6398
# Epoch 27/100 - Validation Accuracy: 0.9214 - Validation AUC: 0.5917
# Epoch 28/100 - Validation Accuracy: 0.9271 - Validation AUC: 0.6110
# Epoch 29/100 - Validation Accuracy: 0.9277 - Validation AUC: 0.6038
# Epoch 30/100 - Validation Accuracy: 0.9241 - Validation AUC: 0.6243
# Epoch 31/100 - Validation Accuracy: 0.9205 - Validation AUC: 0.6236
# Epoch 32/100 - Validation Accuracy: 0.9181 - Validation AUC: 0.6199
# Early stopping triggered.
# Training process for appliance Dish washer01.
# Epoch 1/100 - Validation Accuracy: 0.9682 - Validation AUC: 0.5464
# Epoch 2/100 - Validation Accuracy: 0.9685 - Validation AUC: 0.6082
# Epoch 3/100 - Validation Accuracy: 0.9607 - Validation AUC: 0.6491
# Epoch 4/100 - Validation Accuracy: 0.9627 - Validation AUC: 0.6165
# Epoch 5/100 - Validation Accuracy: 0.9607 - Validation AUC: 0.6434
# Epoch 6/100 - Validation Accuracy: 0.9673 - Validation AUC: 0.6216
# Epoch 7/100 - Validation Accuracy: 0.9670 - Validation AUC: 0.6439
# Epoch 8/100 - Validation Accuracy: 0.9656 - Validation AUC: 0.6544
# Epoch 9/100 - Validation Accuracy: 0.9457 - Validation AUC: 0.6469
# Epoch 10/100 - Validation Accuracy: 0.9580 - Validation AUC: 0.6168
# Epoch 11/100 - Validation Accuracy: 0.9590 - Validation AUC: 0.6342
# Epoch 12/100 - Validation Accuracy: 0.9666 - Validation AUC: 0.5849
# Epoch 13/100 - Validation Accuracy: 0.9636 - Validation AUC: 0.6253
# Epoch 14/100 - Validation Accuracy: 0.9653 - Validation AUC: 0.6570
# Epoch 15/100 - Validation Accuracy: 0.9680 - Validation AUC: 0.5744
# Epoch 16/100 - Validation Accuracy: 0.9622 - Validation AUC: 0.6218
# Epoch 17/100 - Validation Accuracy: 0.9590 - Validation AUC: 0.6370
# Epoch 18/100 - Validation Accuracy: 0.9627 - Validation AUC: 0.6277
# Epoch 19/100 - Validation Accuracy: 0.9683 - Validation AUC: 0.6110
# Epoch 20/100 - Validation Accuracy: 0.9665 - Validation AUC: 0.6044
# Epoch 21/100 - Validation Accuracy: 0.9671 - Validation AUC: 0.6131
# Epoch 22/100 - Validation Accuracy: 0.9690 - Validation AUC: 0.6309
# Epoch 23/100 - Validation Accuracy: 0.9687 - Validation AUC: 0.6139
# Epoch 24/100 - Validation Accuracy: 0.9627 - Validation AUC: 0.6081
# Epoch 25/100 - Validation Accuracy: 0.9658 - Validation AUC: 0.6040
# Epoch 26/100 - Validation Accuracy: 0.9660 - Validation AUC: 0.6350
# Epoch 27/100 - Validation Accuracy: 0.9569 - Validation AUC: 0.6303
# Epoch 28/100 - Validation Accuracy: 0.9682 - Validation AUC: 0.6361
# Epoch 29/100 - Validation Accuracy: 0.9689 - Validation AUC: 0.6280
# Epoch 30/100 - Validation Accuracy: 0.9671 - Validation AUC: 0.6103
# Epoch 31/100 - Validation Accuracy: 0.9692 - Validation AUC: 0.6114
# Epoch 32/100 - Validation Accuracy: 0.9668 - Validation AUC: 0.6074
# Epoch 33/100 - Validation Accuracy: 0.9692 - Validation AUC: 0.6142
# Epoch 34/100 - Validation Accuracy: 0.9585 - Validation AUC: 0.6535
# Early stopping triggered.
# Training process for appliance Microwave01.
# Epoch 1/100 - Validation Accuracy: 0.9806 - Validation AUC: 0.6692
# Epoch 2/100 - Validation Accuracy: 0.9784 - Validation AUC: 0.7563
# Epoch 3/100 - Validation Accuracy: 0.9813 - Validation AUC: 0.7177
# Epoch 4/100 - Validation Accuracy: 0.9828 - Validation AUC: 0.7225
# Epoch 5/100 - Validation Accuracy: 0.9833 - Validation AUC: 0.6986
# Epoch 6/100 - Validation Accuracy: 0.9835 - Validation AUC: 0.7268
# Epoch 7/100 - Validation Accuracy: 0.9796 - Validation AUC: 0.7288
# Epoch 8/100 - Validation Accuracy: 0.9797 - Validation AUC: 0.7490
# Epoch 9/100 - Validation Accuracy: 0.9803 - Validation AUC: 0.7332
# Epoch 10/100 - Validation Accuracy: 0.9833 - Validation AUC: 0.7307
# Epoch 11/100 - Validation Accuracy: 0.9811 - Validation AUC: 0.7376
# Epoch 12/100 - Validation Accuracy: 0.9842 - Validation AUC: 0.7111
# Epoch 13/100 - Validation Accuracy: 0.9825 - Validation AUC: 0.7664
# Epoch 14/100 - Validation Accuracy: 0.9852 - Validation AUC: 0.7397
# Epoch 15/100 - Validation Accuracy: 0.9833 - Validation AUC: 0.7267
# Epoch 16/100 - Validation Accuracy: 0.9813 - Validation AUC: 0.7538
# Epoch 17/100 - Validation Accuracy: 0.9719 - Validation AUC: 0.6888
# Epoch 18/100 - Validation Accuracy: 0.9787 - Validation AUC: 0.7043
# Epoch 19/100 - Validation Accuracy: 0.9803 - Validation AUC: 0.7011
# Epoch 20/100 - Validation Accuracy: 0.9816 - Validation AUC: 0.7178
# Epoch 21/100 - Validation Accuracy: 0.9837 - Validation AUC: 0.6828
# Epoch 22/100 - Validation Accuracy: 0.9849 - Validation AUC: 0.7034
# Epoch 23/100 - Validation Accuracy: 0.9821 - Validation AUC: 0.7382
# Epoch 24/100 - Validation Accuracy: 0.9777 - Validation AUC: 0.7319
# Epoch 25/100 - Validation Accuracy: 0.9813 - Validation AUC: 0.7457
# Epoch 26/100 - Validation Accuracy: 0.9769 - Validation AUC: 0.7074
# Epoch 27/100 - Validation Accuracy: 0.9821 - Validation AUC: 0.6900
# Epoch 28/100 - Validation Accuracy: 0.9830 - Validation AUC: 0.7306
# Epoch 29/100 - Validation Accuracy: 0.9842 - Validation AUC: 0.7151
# Epoch 30/100 - Validation Accuracy: 0.9849 - Validation AUC: 0.7516
# Epoch 31/100 - Validation Accuracy: 0.9818 - Validation AUC: 0.7259
# Epoch 32/100 - Validation Accuracy: 0.9842 - Validation AUC: 0.7312
# Epoch 33/100 - Validation Accuracy: 0.9772 - Validation AUC: 0.7116
# Early stopping triggered.
# Training process for appliance Washer dryer01.
# Epoch 1/100 - Validation Accuracy: 0.9763 - Validation AUC: 0.8687
# Epoch 2/100 - Validation Accuracy: 0.9808 - Validation AUC: 0.9111
# Epoch 3/100 - Validation Accuracy: 0.9769 - Validation AUC: 0.8524
# Epoch 4/100 - Validation Accuracy: 0.9770 - Validation AUC: 0.8581
# Epoch 5/100 - Validation Accuracy: 0.9782 - Validation AUC: 0.8642
# Epoch 6/100 - Validation Accuracy: 0.9738 - Validation AUC: 0.8605
# Epoch 7/100 - Validation Accuracy: 0.9763 - Validation AUC: 0.9143
# Epoch 8/100 - Validation Accuracy: 0.9801 - Validation AUC: 0.8997
# Epoch 9/100 - Validation Accuracy: 0.9825 - Validation AUC: 0.8982
# Epoch 10/100 - Validation Accuracy: 0.9831 - Validation AUC: 0.8862
# Epoch 11/100 - Validation Accuracy: 0.9813 - Validation AUC: 0.8934
# Epoch 12/100 - Validation Accuracy: 0.9818 - Validation AUC: 0.8923
# Epoch 13/100 - Validation Accuracy: 0.9784 - Validation AUC: 0.8477
# Epoch 14/100 - Validation Accuracy: 0.9828 - Validation AUC: 0.8943
# Epoch 15/100 - Validation Accuracy: 0.9748 - Validation AUC: 0.8831
# Epoch 16/100 - Validation Accuracy: 0.9801 - Validation AUC: 0.8914
# Epoch 17/100 - Validation Accuracy: 0.9809 - Validation AUC: 0.9015
# Epoch 18/100 - Validation Accuracy: 0.9809 - Validation AUC: 0.8974
# Epoch 19/100 - Validation Accuracy: 0.9820 - Validation AUC: 0.9214
# Epoch 20/100 - Validation Accuracy: 0.9796 - Validation AUC: 0.9050
# Epoch 21/100 - Validation Accuracy: 0.9791 - Validation AUC: 0.8895
# Epoch 22/100 - Validation Accuracy: 0.9779 - Validation AUC: 0.8861
# Epoch 23/100 - Validation Accuracy: 0.9750 - Validation AUC: 0.8901
# Epoch 24/100 - Validation Accuracy: 0.9792 - Validation AUC: 0.9117
# Epoch 25/100 - Validation Accuracy: 0.9806 - Validation AUC: 0.9000
# Epoch 26/100 - Validation Accuracy: 0.9723 - Validation AUC: 0.8804
# Epoch 27/100 - Validation Accuracy: 0.9784 - Validation AUC: 0.9085
# Epoch 28/100 - Validation Accuracy: 0.9770 - Validation AUC: 0.8967
# Epoch 29/100 - Validation Accuracy: 0.9809 - Validation AUC: 0.8919
# Epoch 30/100 - Validation Accuracy: 0.9821 - Validation AUC: 0.9049
# Epoch 31/100 - Validation Accuracy: 0.9797 - Validation AUC: 0.9064
# Epoch 32/100 - Validation Accuracy: 0.9786 - Validation AUC: 0.8975
# Epoch 33/100 - Validation Accuracy: 0.9830 - Validation AUC: 0.9013
# Epoch 34/100 - Validation Accuracy: 0.9816 - Validation AUC: 0.9019
# Epoch 35/100 - Validation Accuracy: 0.9818 - Validation AUC: 0.8910
# Epoch 36/100 - Validation Accuracy: 0.9806 - Validation AUC: 0.8820
# Epoch 37/100 - Validation Accuracy: 0.9769 - Validation AUC: 0.9035
# Epoch 38/100 - Validation Accuracy: 0.9775 - Validation AUC: 0.9025
# Epoch 39/100 - Validation Accuracy: 0.9763 - Validation AUC: 0.8922
# Early stopping triggered.
# Training process for appliance Washer dryer02.
# Epoch 1/100 - Validation Accuracy: 0.9409 - Validation AUC: 0.7579
# Epoch 2/100 - Validation Accuracy: 0.9483 - Validation AUC: 0.7925
# Epoch 3/100 - Validation Accuracy: 0.9508 - Validation AUC: 0.7808
# Epoch 4/100 - Validation Accuracy: 0.9425 - Validation AUC: 0.7841
# Epoch 5/100 - Validation Accuracy: 0.9430 - Validation AUC: 0.8176
# Epoch 6/100 - Validation Accuracy: 0.9469 - Validation AUC: 0.8110
# Epoch 7/100 - Validation Accuracy: 0.9493 - Validation AUC: 0.8018
# Epoch 8/100 - Validation Accuracy: 0.9505 - Validation AUC: 0.7920
# Epoch 9/100 - Validation Accuracy: 0.9472 - Validation AUC: 0.7823
# Epoch 10/100 - Validation Accuracy: 0.9472 - Validation AUC: 0.7587
# Epoch 11/100 - Validation Accuracy: 0.9469 - Validation AUC: 0.7743
# Epoch 12/100 - Validation Accuracy: 0.9437 - Validation AUC: 0.7996
# Epoch 13/100 - Validation Accuracy: 0.9489 - Validation AUC: 0.7929
# Epoch 14/100 - Validation Accuracy: 0.9445 - Validation AUC: 0.8132
# Epoch 15/100 - Validation Accuracy: 0.9484 - Validation AUC: 0.8179
# Epoch 16/100 - Validation Accuracy: 0.9460 - Validation AUC: 0.8227
# Epoch 17/100 - Validation Accuracy: 0.9508 - Validation AUC: 0.8070
# Epoch 18/100 - Validation Accuracy: 0.9518 - Validation AUC: 0.8058
# Epoch 19/100 - Validation Accuracy: 0.9489 - Validation AUC: 0.7911
# Epoch 20/100 - Validation Accuracy: 0.9481 - Validation AUC: 0.8055
# Epoch 21/100 - Validation Accuracy: 0.9491 - Validation AUC: 0.8000
# Epoch 22/100 - Validation Accuracy: 0.9462 - Validation AUC: 0.7818
# Epoch 23/100 - Validation Accuracy: 0.9455 - Validation AUC: 0.8024
# Epoch 24/100 - Validation Accuracy: 0.9491 - Validation AUC: 0.8174
# Epoch 25/100 - Validation Accuracy: 0.9493 - Validation AUC: 0.7896
# Epoch 26/100 - Validation Accuracy: 0.9471 - Validation AUC: 0.7840
# Epoch 27/100 - Validation Accuracy: 0.9455 - Validation AUC: 0.7971
# Epoch 28/100 - Validation Accuracy: 0.9351 - Validation AUC: 0.8124
# Epoch 29/100 - Validation Accuracy: 0.9476 - Validation AUC: 0.8035
# Epoch 30/100 - Validation Accuracy: 0.9452 - Validation AUC: 0.8153
# Epoch 31/100 - Validation Accuracy: 0.9440 - Validation AUC: 0.8076
# Epoch 32/100 - Validation Accuracy: 0.9488 - Validation AUC: 0.7989
# Epoch 33/100 - Validation Accuracy: 0.9488 - Validation AUC: 0.8172
# Epoch 34/100 - Validation Accuracy: 0.9498 - Validation AUC: 0.8012
# Epoch 35/100 - Validation Accuracy: 0.9510 - Validation AUC: 0.8115
# Epoch 36/100 - Validation Accuracy: 0.9503 - Validation AUC: 0.8303
# Epoch 37/100 - Validation Accuracy: 0.9501 - Validation AUC: 0.8294
# Epoch 38/100 - Validation Accuracy: 0.9440 - Validation AUC: 0.7954
# Epoch 39/100 - Validation Accuracy: 0.9484 - Validation AUC: 0.7987
# Epoch 40/100 - Validation Accuracy: 0.9494 - Validation AUC: 0.7993
# Epoch 41/100 - Validation Accuracy: 0.9500 - Validation AUC: 0.7934
# Epoch 42/100 - Validation Accuracy: 0.9452 - Validation AUC: 0.8197
# Epoch 43/100 - Validation Accuracy: 0.9500 - Validation AUC: 0.8083
# Epoch 44/100 - Validation Accuracy: 0.9484 - Validation AUC: 0.7900
# Epoch 45/100 - Validation Accuracy: 0.9469 - Validation AUC: 0.8014
# Epoch 46/100 - Validation Accuracy: 0.9466 - Validation AUC: 0.8143
# Epoch 47/100 - Validation Accuracy: 0.9399 - Validation AUC: 0.7993
# Epoch 48/100 - Validation Accuracy: 0.9431 - Validation AUC: 0.8063
# Epoch 49/100 - Validation Accuracy: 0.9471 - Validation AUC: 0.7927
# Epoch 50/100 - Validation Accuracy: 0.9454 - Validation AUC: 0.7988
# Epoch 51/100 - Validation Accuracy: 0.9462 - Validation AUC: 0.8019
# Epoch 52/100 - Validation Accuracy: 0.9520 - Validation AUC: 0.8129
# Epoch 53/100 - Validation Accuracy: 0.9556 - Validation AUC: 0.8105
# Epoch 54/100 - Validation Accuracy: 0.9467 - Validation AUC: 0.7934
# Epoch 55/100 - Validation Accuracy: 0.9438 - Validation AUC: 0.7665
# Epoch 56/100 - Validation Accuracy: 0.9489 - Validation AUC: 0.7999
# Early stopping triggered.

# %%
# Mostrar resultados
for column, metrics in results.items():
    print(f"Column: {column}")
    for model_name, scores in metrics.items():
        print(f"  Model: {model_name}")
        print(f"    Accuracy: {scores['accuracy']:.4f}")
        print(f"    AUC: {scores['auc']:.4f}")
        print(f"    F1 Score: {scores['f1_score']:.4f}")
        print(f"    Confusion Matrix:\n{scores['confusion_matrix']}")
# Out:
# Column: Fridge01
#   Model: MLP
#     Accuracy: 0.9142
#     AUC: 0.5047
#     F1 Score: 0.9551
#     Confusion Matrix:
# [[4, 131], [37, 1786]]
# Column: Dish washer01
#   Model: MLP
#     Accuracy: 0.9673
#     AUC: 0.5065
#     F1 Score: 0.0303
#     Confusion Matrix:
# [[1893, 10], [54, 1]]
# Column: Microwave01
#   Model: MLP
#     Accuracy: 0.8611
#     AUC: 0.5124
#     F1 Score: 0.0355
#     Confusion Matrix:
# [[1681, 244], [28, 5]]
# Column: Washer dryer01
#   Model: MLP
#     Accuracy: 0.7799
#     AUC: 0.5159
#     F1 Score: 0.1113
#     Confusion Matrix:
# [[1500, 331], [100, 27]]
# Column: Washer dryer02
#   Model: MLP
#     Accuracy: 0.8386
#     AUC: 0.5478
#     F1 Score: 0.1856
#     Confusion Matrix:
# [[1606, 157], [159, 36]]
