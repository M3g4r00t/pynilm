# %%
import warnings
warnings.filterwarnings(action="ignore")
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

# %%
window_size = 2040
n_components = 2

# %%
# Cargar las variables independientes (X_train) sin cabecera desde archivo
X_train = np.loadtxt(f'../data/v7/transformed_train_data_comp_{n_components}.csv', delimiter=',')

# Cargar las variables dependientes (y_train) con cabecera desde archivo
y_train = pd.read_csv(f'../data/train_value_min_label_windows_{window_size}_llm.csv')

# Cargar el conjunto de test (X_test sin cabeceras y y_test con cabeceras)
X_test = np.loadtxt(f'../data/v7/transformed_test_data_comp_{n_components}.csv', delimiter=',')
y_test = pd.read_csv(f'../data/test_value_min_label_windows_{window_size}_llm.csv')

# Eliminar la columna "row" que es solo un índice
y_train = y_train.drop(columns=['row'])
y_test = y_test.drop(columns=['row'])

# %%
# Escalar los datos de entrenamiento y test
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(X_train_scaled.shape, X_test_scaled.shape)
# Out:
# (1310, 2) (586, 2)

# %%
# Function to generate the class for each appliance
def generate_class(row, appliance):
    appliance_value = row[appliance]
    other_values = row.drop(appliance).values  # Values for the other appliances

    if appliance_value == 0 and not any(other_values):
        return 'off'
    elif appliance_value == 1 and not any(other_values):
        return 'on'
    elif appliance_value == 0 and any(other_values):
        return 'off w int'
    elif appliance_value == 1 and any(other_values):
        return 'on w int'

# %%
from xgboost import XGBClassifier

# Bucle para realizar clasificación binaria para cada columna (clase)
for col in y_train.columns:
    # Create the class labels for each appliance
    y_train_bin = y_train.apply(lambda row: generate_class(row, col), axis=1)
    y_test_bin = y_test.apply(lambda row: generate_class(row, col), axis=1)
    
    label_encoder = LabelEncoder()
    y_train_bin_encoded = label_encoder.fit_transform(y_train_bin)
    y_test_bin_encoded = label_encoder.transform(y_test_bin)

    # Get unique classes for the current appliance
    unique_classes = np.unique(y_train_bin_encoded)
    
    # Handle class imbalance by computing sample weights
    class_weights = compute_class_weight('balanced', classes=unique_classes, y=y_train_bin_encoded)
    class_weight_dict = {cls: weight for cls, weight in zip(unique_classes, class_weights)}
    sample_weight = np.array([class_weight_dict[cls] for cls in y_train_bin_encoded])
    
    # Train XGBoost with class weights
    xgb_clf = XGBClassifier(
        eval_metric='mlogloss'
    )

    xgb_clf.fit(X_train_scaled, y_train_bin_encoded, sample_weight=sample_weight)

    # Create mapping for target names based on the fitted label encoder
    class_mapping = {i: label for i, label in enumerate(label_encoder.classes_)}

    # Make predictions
    y_pred_bin = xgb_clf.predict(X_test_scaled)
    y_pred_proba = xgb_clf.predict_proba(X_test_scaled)

    # Verificar que haya más de una clase en el conjunto de entrenamiento
    if len(np.unique(y_test_bin_encoded)) > 1:
        # Calculate metrics
        accuracy = accuracy_score(y_test_bin_encoded, y_pred_bin)
        f1_macro = f1_score(y_test_bin_encoded, y_pred_bin, average="macro")
        f1_weighted = f1_score(y_test_bin_encoded, y_pred_bin, average="weighted")
        # Check if there are more than two classes to calculate AUC
        if len(np.unique(y_test_bin_encoded)) > 2:
            auc_macro = roc_auc_score(y_test_bin_encoded, y_pred_proba, multi_class="ovr", average="macro")
            auc_weighted = roc_auc_score(y_test_bin_encoded, y_pred_proba, multi_class="ovr", average="weighted")
        else:
            # If only two classes, calculate AUC differently
            auc_macro = roc_auc_score(y_test_bin_encoded, y_pred_proba[:, 1])  # Use probabilities of the positive class
            auc_weighted = auc_macro

        
        # Get unique classes in the predictions
        unique_pred_classes = np.unique(y_pred_bin)

        # Create the classification report using the unique classes found
        report = classification_report(
            y_test_bin_encoded, 
            y_pred_bin, 
            target_names=[class_mapping[label] for label in unique_pred_classes],
            labels=unique_pred_classes
        )
        cm = confusion_matrix(y_test_bin_encoded, y_pred_bin)

        # Mostrar resultados
        print(f"Resultados para la clase {col}:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"F1 Score (macro): {f1_macro:.4f}")
        print(f"F1 Score (weighted): {f1_weighted:.4f}")
        print(f"AUC (macro): {auc_macro:.4f}")
        print(f"AUC (weighted): {auc_weighted:.4f}")
        print("Classification Report:\n", report)
        print(f"Confusion Matrix:\n{cm}")
# Out:
# Resultados para la clase Sockets01:
# Accuracy: 0.9130
# F1 Score (macro): 0.6134
# F1 Score (weighted): 0.9072
# AUC (macro): 0.8938
# AUC (weighted): 0.9316
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.87      0.99      0.93       268
#    off w int       0.96      0.87      0.91       310
#     on w int       0.00      0.00      0.00         8
#
#     accuracy                           0.91       586
#    macro avg       0.61      0.62      0.61       586
# weighted avg       0.91      0.91      0.91       586
#
# Confusion Matrix:
# [[264   4   0]
#  [ 38 271   1]
#  [  0   8   0]]
# Resultados para la clase Sockets02:
# Accuracy: 0.9300
# F1 Score (macro): 0.9300
# F1 Score (weighted): 0.9301
# AUC (macro): 0.9392
# AUC (weighted): 0.9392
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      0.99      0.93       268
#    off w int       0.99      0.88      0.93       318
#
#     accuracy                           0.93       586
#    macro avg       0.93      0.93      0.93       586
# weighted avg       0.94      0.93      0.93       586
#
# Confusion Matrix:
# [[264   4]
#  [ 37 281]]
# Resultados para la clase Light01:
# Accuracy: 0.9249
# F1 Score (macro): 0.6171
# F1 Score (weighted): 0.9258
# AUC (macro): 0.9398
# AUC (weighted): 0.9398
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.87      0.99      0.92       268
#    off w int       0.99      0.87      0.93       318
#     on w int       0.00      0.00      0.00         0
#
#     accuracy                           0.92       586
#    macro avg       0.62      0.62      0.62       586
# weighted avg       0.93      0.92      0.93       586
#
# Confusion Matrix:
# [[264   4   0]
#  [ 39 278   1]
#  [  0   0   0]]
# Resultados para la clase CE appliance01:
# Accuracy: 0.7235
# F1 Score (macro): 0.6520
# F1 Score (weighted): 0.7069
# AUC (macro): 0.8450
# AUC (weighted): 0.8635
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.87      0.99      0.92       268
#           on       0.51      0.36      0.42       146
#     on w int       0.59      0.63      0.61       172
#
#     accuracy                           0.72       586
#    macro avg       0.66      0.66      0.65       586
# weighted avg       0.70      0.72      0.71       586
#
# Confusion Matrix:
# [[264   2   2]
#  [ 22  52  72]
#  [ 17  47 108]]
# Resultados para la clase Fridge01:
# Accuracy: 0.8413
# F1 Score (macro): 0.6100
# F1 Score (weighted): 0.8321
# AUC (macro): 0.8630
# AUC (weighted): 0.9012
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      0.99      0.93       268
#    off w int       0.87      0.80      0.83       284
#     on w int       0.08      0.06      0.07        34
#
#     accuracy                           0.84       586
#    macro avg       0.61      0.61      0.61       586
# weighted avg       0.83      0.84      0.83       586
#
# Confusion Matrix:
# [[264   3   1]
#  [ 36 227  21]
#  [  1  31   2]]
# Resultados para la clase Waste disposal unit01:
# Accuracy: 0.9300
# F1 Score (macro): 0.9300
# F1 Score (weighted): 0.9301
# AUC (macro): 0.9392
# AUC (weighted): 0.9392
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      0.99      0.93       268
#    off w int       0.99      0.88      0.93       318
#
#     accuracy                           0.93       586
#    macro avg       0.93      0.93      0.93       586
# weighted avg       0.94      0.93      0.93       586
#
# Confusion Matrix:
# [[264   4]
#  [ 37 281]]
# Resultados para la clase Dish washer01:
# Accuracy: 0.9198
# F1 Score (macro): 0.6159
# F1 Score (weighted): 0.9189
# AUC (macro): 0.8881
# AUC (weighted): 0.9363
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.87      0.99      0.93       268
#    off w int       0.98      0.87      0.92       315
#     on w int       0.00      0.00      0.00         3
#
#     accuracy                           0.92       586
#    macro avg       0.62      0.62      0.62       586
# weighted avg       0.92      0.92      0.92       586
#
# Confusion Matrix:
# [[264   4   0]
#  [ 38 275   2]
#  [  0   3   0]]
# Resultados para la clase Electric furnace01:
# Accuracy: 0.9266
# F1 Score (macro): 0.9266
# F1 Score (weighted): 0.9267
# AUC (macro): 0.9401
# AUC (weighted): 0.9401
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.87      0.99      0.92       268
#    off w int       0.99      0.88      0.93       318
#
#     accuracy                           0.93       586
#    macro avg       0.93      0.93      0.93       586
# weighted avg       0.93      0.93      0.93       586
#
# Confusion Matrix:
# [[264   4]
#  [ 39 279]]
# Resultados para la clase Light02:
# Accuracy: 0.7150
# F1 Score (macro): 0.6210
# F1 Score (weighted): 0.6944
# AUC (macro): 0.8369
# AUC (weighted): 0.8567
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.87      0.99      0.93       268
#    off w int       0.60      0.64      0.62       192
#     on w int       0.41      0.26      0.32       126
#
#     accuracy                           0.72       586
#    macro avg       0.63      0.63      0.62       586
# weighted avg       0.68      0.72      0.69       586
#
# Confusion Matrix:
# [[264   2   2]
#  [ 25 122  45]
#  [ 13  80  33]]
# Resultados para la clase Sockets03:
# Accuracy: 0.8618
# F1 Score (macro): 0.5952
# F1 Score (weighted): 0.8796
# AUC (macro): 0.8697
# AUC (weighted): 0.9295
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      0.99      0.93       268
#    off w int       0.96      0.77      0.86       311
#     on w int       0.00      0.00      0.00         7
#
#     accuracy                           0.86       586
#    macro avg       0.61      0.59      0.60       586
# weighted avg       0.91      0.86      0.88       586
#
# Confusion Matrix:
# [[264   3   1]
#  [ 37 241  33]
#  [  0   7   0]]
# Resultados para la clase Light03:
# Accuracy: 0.9300
# F1 Score (macro): 0.9300
# F1 Score (weighted): 0.9301
# AUC (macro): 0.9392
# AUC (weighted): 0.9392
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      0.99      0.93       268
#    off w int       0.99      0.88      0.93       318
#
#     accuracy                           0.93       586
#    macro avg       0.93      0.93      0.93       586
# weighted avg       0.94      0.93      0.93       586
#
# Confusion Matrix:
# [[264   4]
#  [ 37 281]]
# Resultados para la clase Microwave01:
# Accuracy: 0.9249
# F1 Score (macro): 0.6177
# F1 Score (weighted): 0.9265
# AUC (macro): 0.9387
# AUC (weighted): 0.9387
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.87      0.99      0.93       268
#    off w int       0.99      0.87      0.93       318
#     on w int       0.00      0.00      0.00         0
#
#     accuracy                           0.92       586
#    macro avg       0.62      0.62      0.62       586
# weighted avg       0.93      0.92      0.93       586
#
# Confusion Matrix:
# [[264   4   0]
#  [ 38 278   2]
#  [  0   0   0]]
# Resultados para la clase Light04:
# Accuracy: 0.7850
# F1 Score (macro): 0.6900
# F1 Score (weighted): 0.7724
# AUC (macro): 0.8732
# AUC (weighted): 0.8883
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      0.99      0.93       268
#    off w int       0.75      0.73      0.74       226
#     on w int       0.48      0.35      0.41        92
#
#     accuracy                           0.78       586
#    macro avg       0.70      0.69      0.69       586
# weighted avg       0.77      0.78      0.77       586
#
# Confusion Matrix:
# [[264   3   1]
#  [ 29 164  33]
#  [  7  53  32]]
# Resultados para la clase Smoke alarm01:
# Accuracy: 0.9300
# F1 Score (macro): 0.9300
# F1 Score (weighted): 0.9301
# AUC (macro): 0.9392
# AUC (weighted): 0.9392
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      0.99      0.93       268
#    off w int       0.99      0.88      0.93       318
#
#     accuracy                           0.93       586
#    macro avg       0.93      0.93      0.93       586
# weighted avg       0.94      0.93      0.93       586
#
# Confusion Matrix:
# [[264   4]
#  [ 37 281]]
# Resultados para la clase Light05:
# Accuracy: 0.7628
# F1 Score (macro): 0.6385
# F1 Score (weighted): 0.7556
# AUC (macro): 0.8617
# AUC (weighted): 0.8839
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      0.99      0.93       268
#    off w int       0.76      0.67      0.71       244
#     on w int       0.28      0.27      0.28        74
#
#     accuracy                           0.76       586
#    macro avg       0.64      0.64      0.64       586
# weighted avg       0.75      0.76      0.76       586
#
# Confusion Matrix:
# [[264   2   2]
#  [ 32 163  49]
#  [  5  49  20]]
# Resultados para la clase Unknown01:
# Accuracy: 0.9164
# F1 Score (macro): 0.6162
# F1 Score (weighted): 0.9209
# AUC (macro): 0.8083
# AUC (weighted): 0.9391
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      0.99      0.93       268
#    off w int       0.99      0.86      0.92       316
#     on w int       0.00      0.00      0.00         2
#
#     accuracy                           0.92       586
#    macro avg       0.62      0.62      0.62       586
# weighted avg       0.93      0.92      0.92       586
#
# Confusion Matrix:
# [[264   3   1]
#  [ 36 273   7]
#  [  1   1   0]]
# Resultados para la clase Sockets04:
# Accuracy: 0.8652
# F1 Score (macro): 0.5955
# F1 Score (weighted): 0.8904
# AUC (macro): 0.9366
# AUC (weighted): 0.9366
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.87      0.99      0.93       268
#    off w int       0.98      0.76      0.86       318
#     on w int       0.00      0.00      0.00         0
#
#     accuracy                           0.87       586
#    macro avg       0.62      0.58      0.60       586
# weighted avg       0.93      0.87      0.89       586
#
# Confusion Matrix:
# [[264   4   0]
#  [ 38 243  37]
#  [  0   0   0]]
# Resultados para la clase Sockets05:
# Accuracy: 0.9061
# F1 Score (macro): 0.6110
# F1 Score (weighted): 0.9141
# AUC (macro): 0.9334
# AUC (weighted): 0.9372
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.87      0.99      0.93       268
#    off w int       0.98      0.84      0.91       317
#     on w int       0.00      0.00      0.00         1
#
#     accuracy                           0.91       586
#    macro avg       0.62      0.61      0.61       586
# weighted avg       0.93      0.91      0.91       586
#
# Confusion Matrix:
# [[264   4   0]
#  [ 38 267  12]
#  [  0   1   0]]
# Resultados para la clase Washer dryer01:
# Accuracy: 0.9198
# F1 Score (macro): 0.6164
# F1 Score (weighted): 0.9196
# AUC (macro): 0.9165
# AUC (weighted): 0.9369
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      0.99      0.93       268
#    off w int       0.98      0.87      0.92       315
#     on w int       0.00      0.00      0.00         3
#
#     accuracy                           0.92       586
#    macro avg       0.62      0.62      0.62       586
# weighted avg       0.93      0.92      0.92       586
#
# Confusion Matrix:
# [[264   4   0]
#  [ 37 275   3]
#  [  0   3   0]]
# Resultados para la clase Washer dryer02:
# Accuracy: 0.8925
# F1 Score (macro): 0.6756
# F1 Score (weighted): 0.8898
# AUC (macro): 0.8907
# AUC (weighted): 0.9237
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.87      0.99      0.93       268
#    off w int       0.94      0.85      0.89       302
#     on w int       0.23      0.19      0.21        16
#
#     accuracy                           0.89       586
#    macro avg       0.68      0.67      0.68       586
# weighted avg       0.89      0.89      0.89       586
#
# Confusion Matrix:
# [[264   3   1]
#  [ 37 256   9]
#  [  1  12   3]]
