# %%
import warnings
warnings.filterwarnings(action="ignore")
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

# %%
window_size = 56
n_components = 60

# %%
# Cargar las variables independientes (X_train) sin cabecera desde archivo
X_train = np.loadtxt(f'../data/v8/transformed_train_data_comp_{n_components}.csv', delimiter=',')

# Cargar las variables dependientes (y_train) con cabecera desde archivo
y_train = pd.read_csv(f'../data/train_value_min_label_windows_{window_size}_llm.csv')

# Cargar el conjunto de test (X_test sin cabeceras y y_test con cabeceras)
X_test = np.loadtxt(f'../data/v8/transformed_test_data_comp_{n_components}.csv', delimiter=',')
y_test = pd.read_csv(f'../data/test_value_min_label_windows_{window_size}_llm.csv')

# Eliminar la columna "row" que es solo un índice
y_train = y_train.drop(columns=['row'])
y_test = y_test.drop(columns=['row'])

# %%
# Escalar los datos de entrenamiento y test
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Function to generate the class for each appliance
def generate_class(row, appliance):
    appliance_value = row[appliance]
    other_values = row.drop(appliance).values  # Values for the other appliances

    if appliance_value == 0 and not any(other_values):
        return 'off'
    elif appliance_value == 1 and not any(other_values):
        return 'on'
    elif appliance_value == 0 and any(other_values):
        return 'off w int'
    elif appliance_value == 1 and any(other_values):
        return 'on w int'

# %%
from xgboost import XGBClassifier

# Bucle para realizar clasificación binaria para cada columna (clase)
for col in y_train.columns:
    # Create the class labels for each appliance
    y_train_bin = y_train.apply(lambda row: generate_class(row, col), axis=1)
    y_test_bin = y_test.apply(lambda row: generate_class(row, col), axis=1)
    
    label_encoder = LabelEncoder()
    y_train_bin_encoded = label_encoder.fit_transform(y_train_bin)
    y_test_bin_encoded = label_encoder.transform(y_test_bin)

    # Get unique classes for the current appliance
    unique_classes = np.unique(y_train_bin_encoded)
    
    # Handle class imbalance by computing sample weights
    class_weights = compute_class_weight('balanced', classes=unique_classes, y=y_train_bin_encoded)
    class_weight_dict = {cls: weight for cls, weight in zip(unique_classes, class_weights)}
    sample_weight = np.array([class_weight_dict[cls] for cls in y_train_bin_encoded])
    
    # Train XGBoost with class weights
    xgb_clf = XGBClassifier(
        eval_metric='mlogloss'
    )

    xgb_clf.fit(X_train_scaled, y_train_bin_encoded, sample_weight=sample_weight)

    # Create mapping for target names based on the fitted label encoder
    class_mapping = {i: label for i, label in enumerate(label_encoder.classes_)}

    # Make predictions
    y_pred_bin = xgb_clf.predict(X_test_scaled)
    y_pred_proba = xgb_clf.predict_proba(X_test_scaled)

    # Verificar que haya más de una clase en el conjunto de entrenamiento
    if len(np.unique(y_test_bin_encoded)) > 1:
        # Calculate metrics
        accuracy = accuracy_score(y_test_bin_encoded, y_pred_bin)
        f1_macro = f1_score(y_test_bin_encoded, y_pred_bin, average="macro")
        f1_weighted = f1_score(y_test_bin_encoded, y_pred_bin, average="weighted")
        # Check if there are more than two classes to calculate AUC
        if len(np.unique(y_test_bin_encoded)) > 2:
            auc_macro = roc_auc_score(y_test_bin_encoded, y_pred_proba, multi_class="ovr", average="macro")
            auc_weighted = roc_auc_score(y_test_bin_encoded, y_pred_proba, multi_class="ovr", average="weighted")
        else:
            # If only two classes, calculate AUC differently
            auc_macro = roc_auc_score(y_test_bin_encoded, y_pred_proba[:, 1])  # Use probabilities of the positive class
            auc_weighted = auc_macro

        
        # Get unique classes in the predictions
        unique_pred_classes = np.unique(y_pred_bin)

        # Create the classification report using the unique classes found
        report = classification_report(
            y_test_bin_encoded, 
            y_pred_bin, 
            target_names=[class_mapping[label] for label in unique_pred_classes],
            labels=unique_pred_classes
        )
        cm = confusion_matrix(y_test_bin_encoded, y_pred_bin)

        # Mostrar resultados
        print(f"Resultados para la clase {col}:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"F1 Score (macro): {f1_macro:.4f}")
        print(f"F1 Score (weighted): {f1_weighted:.4f}")
        print(f"AUC (macro): {auc_macro:.4f}")
        print(f"AUC (weighted): {auc_weighted:.4f}")
        print("Classification Report:\n", report)
        print(f"Confusion Matrix:\n{cm}")
# Out:
# Resultados para la clase Sockets01:
# Accuracy: 0.9353
# F1 Score (macro): 0.9049
# F1 Score (weighted): 0.9352
# AUC (macro): 0.9612
# AUC (weighted): 0.9443
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       0.99      0.88      0.94     11334
#     on w int       0.91      0.79      0.84       304
#
#     accuracy                           0.94     21364
#    macro avg       0.93      0.89      0.90     21364
# weighted avg       0.94      0.94      0.94     21364
#
# Confusion Matrix:
# [[ 9720     6     0]
#  [ 1286 10023    25]
#  [    0    65   239]]
# Resultados para la clase Sockets02:
# Accuracy: 0.9391
# F1 Score (macro): 0.9391
# F1 Score (weighted): 0.9393
# AUC (macro): 0.9452
# AUC (weighted): 0.9452
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       1.00      0.89      0.94     11638
#
#     accuracy                           0.94     21364
#    macro avg       0.94      0.94      0.94     21364
# weighted avg       0.95      0.94      0.94     21364
#
# Confusion Matrix:
# [[ 9718     8]
#  [ 1292 10346]]
# Resultados para la clase Light01:
# Accuracy: 0.9394
# F1 Score (macro): 0.9393
# F1 Score (weighted): 0.9395
# AUC (macro): 0.9453
# AUC (weighted): 0.9453
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       1.00      0.89      0.94     11638
#
#     accuracy                           0.94     21364
#    macro avg       0.94      0.94      0.94     21364
# weighted avg       0.95      0.94      0.94     21364
#
# Confusion Matrix:
# [[ 9720     6]
#  [ 1289 10349]]
# Resultados para la clase CE appliance01:
# Accuracy: 0.8702
# F1 Score (macro): 0.8275
# F1 Score (weighted): 0.8648
# AUC (macro): 0.9142
# AUC (weighted): 0.9261
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#           on       0.78      0.62      0.69      3643
#     on w int       0.89      0.83      0.86      7995
#
#     accuracy                           0.87     21364
#    macro avg       0.85      0.81      0.83     21364
# weighted avg       0.87      0.87      0.86     21364
#
# Confusion Matrix:
# [[9719    2    5]
#  [ 559 2241  843]
#  [ 735  628 6632]]
# Resultados para la clase Fridge01:
# Accuracy: 0.8254
# F1 Score (macro): 0.7906
# F1 Score (weighted): 0.8198
# AUC (macro): 0.9089
# AUC (weighted): 0.9153
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       0.86      0.64      0.74      7174
#     on w int       0.66      0.74      0.70      4464
#
#     accuracy                           0.83     21364
#    macro avg       0.80      0.79      0.79     21364
# weighted avg       0.83      0.83      0.82     21364
#
# Confusion Matrix:
# [[9720    1    5]
#  [ 875 4597 1702]
#  [ 416  732 3316]]
# Resultados para la clase Waste disposal unit01:
# Accuracy: 0.9391
# F1 Score (macro): 0.9391
# F1 Score (weighted): 0.9393
# AUC (macro): 0.9452
# AUC (weighted): 0.9452
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       1.00      0.89      0.94     11638
#
#     accuracy                           0.94     21364
#    macro avg       0.94      0.94      0.94     21364
# weighted avg       0.95      0.94      0.94     21364
#
# Confusion Matrix:
# [[ 9718     8]
#  [ 1292 10346]]
# Resultados para la clase Dish washer01:
# Accuracy: 0.9331
# F1 Score (macro): 0.6386
# F1 Score (weighted): 0.9308
# AUC (macro): 0.9451
# AUC (weighted): 0.9440
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       0.99      0.89      0.93     11516
#     on w int       0.20      0.02      0.04       122
#
#     accuracy                           0.93     21364
#    macro avg       0.69      0.64      0.64     21364
# weighted avg       0.94      0.93      0.93     21364
#
# Confusion Matrix:
# [[ 9720     6     0]
#  [ 1292 10212    12]
#  [    0   119     3]]
# Resultados para la clase Electric furnace01:
# Accuracy: 0.9349
# F1 Score (macro): 0.6246
# F1 Score (weighted): 0.9369
# AUC (macro): 0.9453
# AUC (weighted): 0.9453
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       1.00      0.88      0.94     11638
#     on w int       0.00      0.00      0.00         0
#
#     accuracy                           0.93     21364
#    macro avg       0.63      0.63      0.62     21364
# weighted avg       0.95      0.93      0.94     21364
#
# Confusion Matrix:
# [[ 9719     7     0]
#  [ 1291 10255    92]
#  [    0     0     0]]
# Resultados para la clase Light02:
# Accuracy: 0.8307
# F1 Score (macro): 0.7869
# F1 Score (weighted): 0.8214
# AUC (macro): 0.9011
# AUC (weighted): 0.9092
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       0.77      0.79      0.78      6973
#     on w int       0.80      0.54      0.65      4665
#
#     accuracy                           0.83     21364
#    macro avg       0.82      0.78      0.79     21364
# weighted avg       0.83      0.83      0.82     21364
#
# Confusion Matrix:
# [[9719    5    2]
#  [ 838 5489  646]
#  [ 457 1668 2540]]
# Resultados para la clase Sockets03:
# Accuracy: 0.8489
# F1 Score (macro): 0.6195
# F1 Score (weighted): 0.8743
# AUC (macro): 0.9047
# AUC (weighted): 0.9384
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       0.98      0.73      0.84     11389
#     on w int       0.05      0.35      0.08       249
#
#     accuracy                           0.85     21364
#    macro avg       0.64      0.69      0.62     21364
# weighted avg       0.92      0.85      0.87     21364
#
# Confusion Matrix:
# [[9719    7    0]
#  [1291 8328 1770]
#  [   0  161   88]]
# Resultados para la clase Light03:
# Accuracy: 0.9391
# F1 Score (macro): 0.9391
# F1 Score (weighted): 0.9393
# AUC (macro): 0.9452
# AUC (weighted): 0.9452
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       1.00      0.89      0.94     11638
#
#     accuracy                           0.94     21364
#    macro avg       0.94      0.94      0.94     21364
# weighted avg       0.95      0.94      0.94     21364
#
# Confusion Matrix:
# [[ 9718     8]
#  [ 1292 10346]]
# Resultados para la clase Microwave01:
# Accuracy: 0.9368
# F1 Score (macro): 0.6658
# F1 Score (weighted): 0.9357
# AUC (macro): 0.9501
# AUC (weighted): 0.9449
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       0.99      0.89      0.94     11576
#     on w int       1.00      0.06      0.12        62
#
#     accuracy                           0.94     21364
#    macro avg       0.96      0.65      0.67     21364
# weighted avg       0.94      0.94      0.94     21364
#
# Confusion Matrix:
# [[ 9721     5     0]
#  [ 1287 10289     0]
#  [    2    56     4]]
# Resultados para la clase Light04:
# Accuracy: 0.8769
# F1 Score (macro): 0.8490
# F1 Score (weighted): 0.8740
# AUC (macro): 0.9242
# AUC (weighted): 0.9272
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       0.92      0.78      0.84      8161
#     on w int       0.77      0.76      0.76      3477
#
#     accuracy                           0.88     21364
#    macro avg       0.86      0.85      0.85     21364
# weighted avg       0.88      0.88      0.87     21364
#
# Confusion Matrix:
# [[9720    2    4]
#  [1007 6382  772]
#  [ 284  561 2632]]
# Resultados para la clase Smoke alarm01:
# Accuracy: 0.9391
# F1 Score (macro): 0.9391
# F1 Score (weighted): 0.9393
# AUC (macro): 0.9452
# AUC (weighted): 0.9452
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       1.00      0.89      0.94     11638
#
#     accuracy                           0.94     21364
#    macro avg       0.94      0.94      0.94     21364
# weighted avg       0.95      0.94      0.94     21364
#
# Confusion Matrix:
# [[ 9718     8]
#  [ 1292 10346]]
# Resultados para la clase Light05:
# Accuracy: 0.8329
# F1 Score (macro): 0.7752
# F1 Score (weighted): 0.8296
# AUC (macro): 0.9066
# AUC (weighted): 0.9128
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       0.87      0.71      0.78      8748
#     on w int       0.57      0.64      0.60      2890
#
#     accuracy                           0.83     21364
#    macro avg       0.78      0.78      0.78     21364
# weighted avg       0.84      0.83      0.83     21364
#
# Confusion Matrix:
# [[9720    2    4]
#  [1152 6232 1364]
#  [ 138  910 1842]]
# Resultados para la clase Unknown01:
# Accuracy: 0.9364
# F1 Score (macro): 0.7737
# F1 Score (weighted): 0.9365
# AUC (macro): 0.8623
# AUC (weighted): 0.9447
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       1.00      0.89      0.94     11554
#     on w int       0.44      0.45      0.44        84
#
#     accuracy                           0.94     21364
#    macro avg       0.77      0.78      0.77     21364
# weighted avg       0.94      0.94      0.94     21364
#
# Confusion Matrix:
# [[ 9721     5     0]
#  [ 1259 10246    49]
#  [   34    12    38]]
# Resultados para la clase Sockets04:
# Accuracy: 0.8835
# F1 Score (macro): 0.6059
# F1 Score (weighted): 0.9063
# AUC (macro): 0.9453
# AUC (weighted): 0.9453
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       1.00      0.79      0.88     11638
#     on w int       0.00      0.00      0.00         0
#
#     accuracy                           0.88     21364
#    macro avg       0.63      0.60      0.61     21364
# weighted avg       0.95      0.88      0.91     21364
#
# Confusion Matrix:
# [[9720    5    1]
#  [1294 9156 1188]
#  [   0    0    0]]
# Resultados para la clase Sockets05:
# Accuracy: 0.9163
# F1 Score (macro): 0.6396
# F1 Score (weighted): 0.9221
# AUC (macro): 0.9001
# AUC (weighted): 0.9426
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       0.99      0.85      0.92     11534
#     on w int       0.04      0.16      0.06       104
#
#     accuracy                           0.92     21364
#    macro avg       0.64      0.67      0.64     21364
# weighted avg       0.94      0.92      0.92     21364
#
# Confusion Matrix:
# [[9720    5    1]
#  [1289 9839  406]
#  [   5   82   17]]
# Resultados para la clase Washer dryer01:
# Accuracy: 0.9388
# F1 Score (macro): 0.9489
# F1 Score (weighted): 0.9389
# AUC (macro): 0.9628
# AUC (weighted): 0.9447
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       1.00      0.89      0.94     11446
#     on w int       0.95      0.99      0.97       192
#
#     accuracy                           0.94     21364
#    macro avg       0.94      0.96      0.95     21364
# weighted avg       0.95      0.94      0.94     21364
#
# Confusion Matrix:
# [[ 9721     5     0]
#  [ 1290 10145    11]
#  [    0     1   191]]
# Resultados para la clase Washer dryer02:
# Accuracy: 0.9275
# F1 Score (macro): 0.8680
# F1 Score (weighted): 0.9268
# AUC (macro): 0.9590
# AUC (weighted): 0.9433
# Classification Report:
#                precision    recall  f1-score   support
#
#          off       0.88      1.00      0.94      9726
#    off w int       0.98      0.88      0.93     11113
#     on w int       0.82      0.68      0.74       525
#
#     accuracy                           0.93     21364
#    macro avg       0.89      0.85      0.87     21364
# weighted avg       0.93      0.93      0.93     21364
#
# Confusion Matrix:
# [[9720    6    0]
#  [1294 9740   79]
#  [   1  169  355]]
